# %%
# %matplotlib notebook
import numpy as np
import geopandas as gpd
import seaborn as sns
import time
import os
import imageio
import plotly.express as px
import plotly
import bar_chart_race as bcr
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation
from matplotlib.pyplot import show
import warnings
import time
# Out:
# /home/nirmala/.local/lib/python3.8/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /tmp/ipykernel_19892/466826767.py:3: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# ...

# %%
df=pd.read_csv('/home/nirmala/timing_final_copy_after_filter.csv')

# %%
df
# Out:
#          state_code  file_closing_days  file_reach_days  decide_close_days  \
# 0    Andhra Pradesh        1000.340859       404.308270           0.423684
# 1             Assam           0.000000         0.000000           0.000000
# 2             Bihar           0.000000         0.000000           0.000000
# 3        Chandigarh           0.000000         0.000000           0.000000
# 4       Chattisgarh           0.000000         0.000000           0.000000
# ..              ...                ...              ...                ...
# 255       Telangana          97.387049        44.757250           0.295233
# 256         Tripura         150.772764        40.976632           0.245770
# 257   Uttar pradesh          69.019989        20.760331           2.170473
# 258     Uttarakhand          92.552775        30.921476           0.303449
# 259     West Bengal          92.027731        17.358586           0.607467
#
#      Year
# 0    2010
# 1    2010
# 2    2010
# 3    2010
# ...

# %%
file_close_result = df.groupby('state_code')['file_closing_days'].mean().reset_index()

# %%
file_reach_result=df.groupby("state_code")['file_reach_days'].mean().reset_index()

# %%
df.describe()
# Out:
#        file_closing_days  file_reach_days  decide_close_days         Year
# count         260.000000       260.000000         260.000000   260.000000
# mean          454.440689       147.595455           2.137880  2013.711538
# std           394.979639       249.351366           3.980196     2.555459
# min             0.000000         0.000000           0.000000  2010.000000
# 25%           144.471969        23.238326           0.087581  2012.000000
# 50%           387.167301        71.164808           0.554880  2014.000000
# 75%           692.604311       168.196528           2.391861  2016.000000
# max          2526.666667      2243.000000          35.291323  2018.000000

# %%
decide_close_result=df.groupby("state_code")['decide_close_days'].mean().reset_index()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 file_close_result=file_close_result.to_frame()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
file_close_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state_code         32 non-null     object
#  1   file_closing_days  32 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 640.0+ bytes

# %%
final=pd.merge(file_close_result,file_reach_result,on="state_code")

# %%
final=pd.merge(decide_close_result,final,on="state_code")

# %%
final
# Out:
#            state_code  decide_close_days  file_closing_days  file_reach_days
# 0      Andhra Pradesh           0.383441         566.131398       153.590987
# 1               Assam           0.651918         395.259223       131.512861
# 2               Bihar           4.223333         559.373442       213.922394
# 3          Chandigarh           6.580416         403.609485        56.540329
# 4         Chattisgarh           3.352453         491.203826       140.667339
# 5      DNH at silvasa           0.139170         504.346354        38.344367
# 6               Delhi           4.430026         436.222948        57.329367
# 7       Diu and daman           0.002064         301.861930        33.003473
# 8                 Goa           8.006905         289.139825        69.345791
# 9            Gujarath           1.644660         382.203463       115.301331
# 10            Haryana           1.303531         397.839030        85.290441
# ...

# %%
final.to_csv("state_time_merge")
