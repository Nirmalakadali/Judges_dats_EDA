# %%
import pandas as pd
import matplotlib.pyplot as plt
   
# data = {'year': [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010],
#         'unemployment_rate': [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3]
#        }
  
# df = pd.DataFrame(data)
df=pd.read_csv(r'/home/nirmala/merged_final.csv')
#df2=df
#plt.figure(figsize=(8,5))
#df2=df2[df2['state']=="Andhra Pradesh"]

#df2
#plt.plot(df2['year'], df2['criminal_count'])
#plt.xlabel('Year')
#plt.title('criminal Count by Year in Tamil Nadu')
#plt.show()
# pip install imageio
output_path1 = '/home/nirmala/Documents/precog_requirement_task_analysis&observations/graphs/'

result = df.groupby('year')['criminal_count'].sum()
result2=df.groupby('year')['noncriminal_count'].sum()
filepath1 = os.path.join(output_path1 + 'criminal vs noncriminal '+'graph.jpg')

result
df_line = result.to_frame()
df_line2=result2.to_frame()
fig, ax = plt.subplots(1, figsize=(10, 10))

df_line=df_line.reset_index()
df_line2=df_line2.reset_index()

df_line
x=df_line['year']
y= df_line['criminal_count']
fig = plt.figure(figsize=(10, 9))
x1=df_line2['year']
y1=df_line2['noncriminal_count']
plt.barh(x,y, color='red')
plt.barh(x1,y1, color='blue')

plt.title('criminal vs noncriminal', fontsize=14)
plt.xlabel('year', fontsize=14)
plt.ylabel('criminal/noncriminal', fontsize=14)
#for i, j in zip(x, y):
 #   plt.annotate(f'({i}, {j})', (i, j), textcoords="offset points", xytext=(0,10), ha='center')
#for i, j in zip(x1, y1):
 #   plt.annotate(f'({i}, {j})', (i, j), textcoords="offset points", xytext=(0,10), ha='center')
chart = fig.get_figure()
chart.savefig(filepath1, dpi=300)
plt.show()
df

# x_coord, y_coord = plt.ginput(1)[0]
# print(f'x: {x_coord}, y: {y_coord}')
# Out:
# <img src="data:image/png;base64,..." width="1000.0000264909539">
# <img src="data:image/png;base64,..." width="1000.0000264909539">
#      year           state  dismissed_count  prison_count  withdrawal_count  \
# 0    2010  Andhra Pradesh            27690             0              1332
# 1    2010           Assam                0             0                 0
# 2    2010           Bihar                0             0                 0
# 3    2010      Chandigarh                0             0                 0
# 4    2010     Chattisgarh                0             0                 0
# ..    ...             ...              ...           ...               ...
# 283  2018       Telangana                0             0                 0
# 284  2018         Tripura                1            23                 0
# 285  2018   Uttar pradesh               75             9               535
# 286  2018     Uttarakhand                1           249                 0
# ...

# %%
import matplotlib as mpl

first_bar = df_line['criminal_count']
first_bar_label = 'criminal_count'
first_bar_color = '#32628d'
second_bar = df_line2['noncriminal_count']
second_bar_label = 'noncriminal_count'
second_bar_color = '#cde01d'
labels = df_line.index
width = 0.4  # the width of the bars
plot_title = 'criminal vs noncriminal'
title_size = 18
fig, ax = plt.subplots(figsize=(10,6), facecolor=(.94, .94, .94))
plt.tight_layout()    
y = np.arange(len(labels))  # Label locations
ax.barh(y + width/2, first_bar, width, label=first_bar_label, color=first_bar_color)
ax.barh(y - width/2, second_bar, width, label=second_bar_label, color=second_bar_color)

# Format ticks
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
title = plt.title(plot_title, pad=20, fontsize=title_size)
title.set_position([.35, 1])

# Adjust subplots

# Set subtitle
tform = ax.get_xaxis_transform() 
rects = ax.patches
for rect in rects:
    # Get X and Y placement of label from rect.
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2
    space = 5
    ha = 'left'
    if x_value < 0:
        space *= -1
        ha = 'right'
    label = '{:,.0f}'.format(x_value)
    plt.annotate(
        label,                      
        (x_value, y_value),         
        xytext=(space, 0),          
        textcoords='offset points',
        va='center',                
        ha=ha)
ax.set_yticklabels(df_line['year'])
ax.legend()

# To show each y-label, not just even ones
plt.yticks(np.arange(min(y), max(y)+1, 1.0))
plt.savefig(filepath1+'.criminal versus noncriminal.jpg', facecolor=(.94, .94, .94))
# Out:
# <img src="data:image/png;base64,..." width="1000.0000264909539">
# /tmp/ipykernel_7968/1457404136.py:46: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
df.info()
yea=df['year'].unique()
sta=df['state'].unique()
sta
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   year                            288 non-null    int64
#  1   state                           288 non-null    object
#  2   dismissed_count                 288 non-null    int64
#  3   prison_count                    288 non-null    int64
#  4   withdrawal_count                288 non-null    int64
#  5   avg_decision_end_per1lakhcases  288 non-null    int64
#  6   avg_fileend_per1lakhcases       288 non-null    int64
#  7   avg_filecourt_per1lakhcases     288 non-null    int64
#  8   pendingcases_count              256 non-null    float64
#  9   pending_casesperlakh            256 non-null    float64
#  10  criminal_count                  288 non-null    int64
#  11  criminal_perlakh                288 non-null    float64
# ...

# %%
from pygooglechart import PieChart3D

def python_pie3D() :
  # initialize chart object, 250 x 250 pixels
  chart = PieChart3D(250, 250)

  # pass your data to the chart object
  chart.add_data([398, 294, 840, 462])

  # make labels for the slices
  chart.set_pie_labels("Lithuania Bulgaria Ukraine Romania".split())

  # render the image
  chart.download('revenue_east_europe.png')
python_pie3D()

# %%
pip install pygooglechart
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1=df
df1=df1.drop(columns=["dismissed_count",'prison_count','withdrawal_count','avg_decision_end_per1lakhcases','avg_fileend_per1lakhcases','avg_filecourt_per1lakhcases','pendingcases_count','pending_casesperlakh','criminal_perlakh','noncriminal_perlakh'])

# %%
df2=df1[df1['state']=="Andhra Pradesh"]
df3=df1[df1['state']=="Assam"]
df4=df1[df1['state']=="Bihar"]
df5=df1[df1['state']=="Chandigarh"]
df6=df1[df1['state']=="Chattisgarh"]
df8=df1[df1['state']=="DNH at silvasa"]
df9=df1[df1['state']=="Delhi"]
df10=df1[df1['state']=="Diu and daman"]
df11=df1[df1['state']=="Goa"]
df12=df1[df1['state']=="Gujarath"]
df13=df1[df1['state']=="Haryana"]
df14=df1[df1['state']=="Himachal Pradesh"]
df15=df1[df1['state']=="Jammu and kashmir"]
df16=df1[df1['state']=="Jharkhand"]
df17=df1[df1['state']=="Karnataka"]
df18=df1[df1['state']=="Kerala"]
df19=df1[df1['state']=="Ladakh"]
df20=df1[df1['state']=="Madhya Pradesh"]
df21=df1[df1['state']=="Maharashtra"]
df22=df1[df1['state']=="Manipur"]
df23=df1[df1['state']=="Meghalaya"]
df24=df1[df1['state']=="Mizoram"]
df25=df1[df1['state']=="Orissa"]
df26=df1[df1['state']=="Punjab"]
df27=df1[df1['state']=="Rajasthan"]
df28=df1[df1['state']=="Sikkim"]
df29=df1[df1['state']=="Tamilnadu"]
df30=df1[df1['state']=="Telangana"]
df31=df1[df1['state']=="Uttar pradesh"]
df32=df1[df1['state']=="Uttarakhand"]
df33=df1[df1['state']=="West Bengal"]

# %%
fig = plt.figure(figsize=(40, 29))

import seaborn as sb
sb.lineplot(x=df2['year'], y=df2['criminal_count'] ,data=df2,label="Andhra pradesh",marker='o')
sb.lineplot(x=df3['year'], y=df3['criminal_count'], data=df3,label="Assam",marker='o')
sb.lineplot(x=df4['year'], y=df4['criminal_count'] ,data=df4,label="Bihar",marker='o')
sb.lineplot(x=df5['year'], y=df5['criminal_count'], data=df5,label="Chandigarh",marker='o')
sb.lineplot(x=df6['year'], y=df6['criminal_count'] ,data=df6,label="Chattisgarh",marker='o')
sb.lineplot(x=df8['year'], y=df8['criminal_count'] ,data=df8,label="DNH at silvasa",marker='o')
sb.lineplot(x=df9['year'], y=df9['criminal_count'], data=df9,label="Delhi",marker='o')
sb.lineplot(x=df10['year'], y=df10['criminal_count'] ,data=df10,label="Diu and daman",marker='o')
sb.lineplot(x=df11['year'], y=df11['criminal_count'], data=df11,label="Goa",marker='o')
sb.lineplot(x=df12['year'], y=df12['criminal_count'] ,data=df12,label="Gujarath",marker='o')
sb.lineplot(x=df13['year'], y=df13['criminal_count'], data=df13,label="Haryana",marker='o')
sb.lineplot(x=df14['year'], y=df14['criminal_count'] ,data=df14,label="Himachal Pradesh",marker='o')
sb.lineplot(x=df15['year'], y=df15['criminal_count'], data=df15,label="Jammu and kashmir",marker='o')
sb.lineplot(x=df16['year'], y=df16['criminal_count'] ,data=df16,label="Jharkhand",marker='o')
sb.lineplot(x=df17['year'], y=df17['criminal_count'], data=df17,label="Karnataka",marker='o')
sb.lineplot(x=df18['year'], y=df18['criminal_count'] ,data=df18,label="Kerala",marker='o')
sb.lineplot(x=df19['year'], y=df19['criminal_count'], data=df19,label="Ladakh",marker='o')
sb.lineplot(x=df20['year'], y=df20['criminal_count'] ,data=df20,label="Madhya Pradesh",marker='o')
sb.lineplot(x=df21['year'], y=df21['criminal_count'], data=df21,label="Maharashtra",marker='o')
sb.lineplot(x=df22['year'], y=df22['criminal_count'] ,data=df22,label="Manipur",marker='o')
sb.lineplot(x=df23['year'], y=df23['criminal_count'], data=df23,label="Meghalaya",marker='o')
sb.lineplot(x=df24['year'], y=df24['criminal_count'] ,data=df24,label="Mizoram",marker='o')
sb.lineplot(x=df25['year'], y=df25['criminal_count'], data=df25,label="Orissa",marker='o')
sb.lineplot(x=df26['year'], y=df26['criminal_count'], data=df26,label="Punjab",marker='o')
sb.lineplot(x=df27['year'], y=df27['criminal_count'], data=df27,label="Rajasthan",marker='o')
sb.lineplot(x=df28['year'], y=df28['criminal_count'], data=df28,label="Sikkim",marker='o')
sb.lineplot(x=df29['year'], y=df29['criminal_count'], data=df29,label="Tamilnadu",marker='o')
sb.lineplot(x=df30['year'], y=df30['criminal_count'], data=df30,label="Telangana",marker='o')
sb.lineplot(x=df31['year'], y=df31['criminal_count'], data=df31,label="Uttar pradesh",marker='o')
sb.lineplot(x=df32['year'], y=df32['criminal_count'], data=df32,label="Uttarakhand",marker='o')
sb.lineplot(x=df33['year'], y=df33['criminal_count'], data=df33,label="West Bengal",marker='o')
# set label

fig=plt.show()
#plotly.offline.plot(fig,filename='dd.html')
# Out:
# <img src="data:image/png;base64,..." width="4000.0001059638157">

# %%
df11 = df2.pivot(index='state', columns='year', values=['criminal_count','noncriminal_count'])

# plot line graph
df11.plot(kind='line')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.animation import FuncAnimation
# %matplotlib notebook
# %matplotlib inline
# Reading data
data = pd.read_csv('/home/nirmala/merged_final.csv')
data
# List of states
states = data['state'].unique()

# List of years
years = data['year'].unique()
years
# Data for each year
prison = data.groupby(['year'])['prison_count'].sum()
dismissed = data.groupby(['year'])['dismissed_count'].sum()
criminal = data.groupby(['year'])['criminal_count'].sum()
non_criminal = data.groupby(['year'])['noncriminal_count'].sum()
withdrawal=data.groupby(['year'])['withdrawal_count'].sum()
total_cases=data.groupby(['year'])['total_cases'].sum()
# Creating figure
fig, ax = plt.subplots(figsize=(10, 5))

# # Stacked bar chart
# def update(year):
#     ax.clear()
#     ax.bar(states, prison[year], label='Prison')
#     ax.bar(states, dismissed[year], bottom=prison[year], label='Dismissed')
#     ax.bar(states, criminal[year], bottom=prison[year]+dismissed[year], label='Criminal')
#     ax.bar(states, non_criminal[year], bottom=prison[year]+dismissed[year]+criminal[year], label='Non_Criminal')
#     ax.bar(states, withdrawal[year], bottom=prison[year]+dismissed[year]+criminal[year]+non_criminal[year], label='withdrawal')
#     ax.bar(states, total_cases[year], bottom=prison[year]+dismissed[year]+criminal[year]+non_criminal[year]+withdrawal[year], label='total_cases')
#     plt.xticks(states, rotation=90)
#     plt.yticks(np.arange(0, 80000, 10000))
#     plt.legend()
#     plt.title("Cases for year - {}".format(year))

# ani = FuncAnimation(fig, update, frames=years, repeat=True)
# plt.show()
def update(year):
    ax.clear()
    ax.bar(states, prison[year], label='Prison')
    ax.bar(states, dismissed[year], bottom=prison[year], label='Dismissed')
    ax.bar(states, criminal[year], bottom=prison[year]+dismissed[year], label='Criminal')
    ax.bar(states, non_criminal[year], bottom=prison[year]+dismissed[year]+criminal[year], label='Non_Criminal')
    ax.bar(states, withdrawal[year], bottom=prison[year]+dismissed[year]+criminal[year]+non_criminal[year], label='withdrawal')
    ax.bar(states, total_cases[year], bottom=prison[year]+dismissed[year]+criminal[year]+non_criminal[year]+withdrawal[year], label='total_cases')
    plt.xticks(states, rotation=90)
    plt.yticks(np.arange(0, 80000, 10000))
    plt.legend()
    plt.title("Cases for year - {}".format(year))

ani = FuncAnimation(fig, update, frames=years, repeat=True)
plt.show()

# %%
# fig, ax = plt.subplots(figsize=(10, 5))

#Stacked bar chart
#def update(year):
#     ax.clear()
#     ax.bar(states, prison[year], label='Prison')
#     ax.bar(states, dismissed[year], bottom=prison[year], label='Dismissed')
# #   ax.bar(states, criminal[year], bottom=prison[year]+dismissed[year], label='Criminal')
#     ax.bar(states, non_criminal[year], bottom=prison[year]+dismissed[year]+criminal[year], label='Non_Criminal')
#     ax.bar(states, non_criminal[year], bottom=prison[year]+dismissed[year]+criminal[year], label='Non_Criminal')

#     plt.xticks(states, rotation=90)
#     plt.yticks(np.arange(0, 80000, 10000))
#     plt.legend()
#     plt.title("Cases for year - {}".format(year))

# ani = FuncAnimation(fig, update, frames=years, repeat=True)
# plt.show()

# %%
# %matplotlib notebook
import numpy as np
import geopandas as gpd
import seaborn as sns
import time
import os
import imageio
import plotly.express as px
import plotly
import bar_chart_race as bcr
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation
from matplotlib.pyplot import show
import warnings
import time
# warnings.filterwarnings("ignore") 

# from pysal.esda.mapclassify import Quantiles, Equal_Interval

# %%
fp = r'/home/nirmala/Maps_with_python-master/india-polygon.shp'
map_df = gpd.read_file(fp)                          # Reads the shape file of India for plotting purpose
map_df_copy = gpd.read_file(fp)
map_df.rename(columns={"st_nm": "state"}, inplace=True)
map_df=map_df.sort_values(by="state")

# %%
df['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chattisgarh',
#        'DNH at silvasa', 'Delhi', 'Diu and daman', 'Goa', 'Gujarath',
#        'Haryana', 'Himachal Pradesh', 'Jammu and kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Orissa', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamilnadu', 'Telangana', 'Tripura', 'Uttar pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
df['state'].replace(to_replace='Chattisgarh' ,value="Chhattisgarh",inplace=True)
df['state'].replace(to_replace='DNH at silvasa' ,value="Dadra and Nagar Haveli",inplace=True)
df['state'].replace(to_replace='Diu and daman' ,value="Daman and Diu",inplace=True)
df['state'].replace(to_replace='Gujarath' ,value="Gujarat",inplace=True)
df['state'].replace(to_replace='Orissa' ,value="Odisha",inplace=True)
df['state'].replace(to_replace='Tamilnadu' ,value="Tamil Nadu",inplace=True)
df['state'].replace(to_replace='Uttar pradesh' ,value="Uttar Pradesh",inplace=True)
df['state'].replace(to_replace='Jammu and kashmir' ,value="Jammu and Kashmir",inplace=True)

# %%
output_path = '/home/nirmala/Documents/precog_requirement_task_analysis&observations/animation/withdrawn/'

# counter for the for loop

# list of years (which are the column names at the moment)
list_of_years = [2010,2011,2012,2013,2014,2015,2016,2017,2018]

# %%
df.tail(50)
# Out:
#      year                   state  dismissed_count  prison_count  \
# 238  2017               Karnataka               32         31053
# 239  2017                  Kerala                6         11728
# 240  2017                  Ladakh                0             0
# 241  2017          Madhya Pradesh                0             0
# 242  2017             Maharashtra               36          6998
# 243  2017                 Manipur                0             3
# 244  2017               Meghalaya                0             5
# 245  2017                 Mizoram                0             0
# 246  2017                  Odisha                7           159
# 247  2017                  Punjab                0             0
# 248  2017               Rajasthan              129          8047
# 249  2017                  Sikkim                2            24
# 250  2017              Tamil Nadu                0             0
# ...

# %%
vmin, vmax = 200, 1200
images=[]
i=1

# %%
for yer in list_of_years:
    df_gif = df[df.year==yer] 
    # Selecting only landslide category
# df=df.drop(columns=['prison_count','withdrawal_count','avg_decision_end_per1lakhcases','avg_fileend_per1lakhcases','avg_filecourt_per1lakhcases','pendingcases_count','criminal_count'])
    count='withdrawal_count'
    columns_to_keep = ['year', 'state',count]
    columns_to_drop = set(df.columns) - set(columns_to_keep)
    df_gif = df_gif.drop(columns=columns_to_drop, axis=1)
    df_dis=df_gif
    df_gif=df_gif.reset_index()
    df_merged=pd.merge(map_df,df_gif,on="state")
    df_merged=df_merged.drop(columns=['id','index'])
    fig, ax = plt.subplots(1, figsize=(10, 10))
    df_merged.plot(column='withdrawal_count',cmap='YlOrRd', linewidth=0.8, ax=ax, edgecolor='0', \
                legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Number of withdrawal_cases"})
    ax.axis('off')
    ax.set_title('Number of withdrawn cases in '+str(yer),fontdict={'fontsize': '20', 'fontweight' : '10'})
    filepath = os.path.join(output_path +'withdrawn '+ str(yer) + 'graph.jpg')
    
    chart = fig.get_figure()
    chart.savefig(filepath, dpi=300)
    images.append(imageio.imread(filepath.format(i)))
    i=i+1
    del df_merged
    del df_gif
# Out:
# <img src="data:image/png;base64,..." width="1000.0000264909539">
# /tmp/ipykernel_7968/3033149341.py:22: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
# <img src="data:image/png;base64,..." width="1000.0000264909539">
# /tmp/ipykernel_7968/3033149341.py:22: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
# <img src="data:image/png;base64,..." width="1000.0000264909539">
# /tmp/ipykernel_7968/3033149341.py:22: DeprecationWarning:
#
# ...

# %%
fig, ax = plt.subplots()
ax.set_title("My animation")
def update(num):
    plt.cla()  #clear the previous frame
    ax.imshow(images[num])

ani = animation.FuncAnimation(fig, update, frames=range(len(images)), blit=False,interval=2000)
ani.save('/home/nirmala/Documents/precog_requirement_task_analysis&observations/animation/withdrawn/withdrawn.gif', writer='imagemagick')
show(ani)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# MovieWriter imagemagick unavailable; using Pillow instead.

# %% [markdown]
# # bar graph

# %%
# df = df.set_index('year')
state=df['state']
dismissed=df['pendingcases_count']
year=df['year']
fig=px.bar(df,x=state,y=dismissed,color=state,animation_frame=year,animation_group=state,range_y=[0,130000],orientation='v')
plotly.offline.plot(fig,filename='pendingcases_count.html')
# Out:
# 'pendingcases_count.html'

# %%
result = df.groupby('year')['dismissed_count'].sum()

# %%
result
df_line = result.to_frame()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   year                            288 non-null    int64
#  1   state                           288 non-null    object
#  2   dismissed_count                 288 non-null    int64
#  3   prison_count                    288 non-null    int64
#  4   withdrawal_count                288 non-null    int64
#  5   avg_decision_end_per1lakhcases  288 non-null    int64
#  6   avg_fileend_per1lakhcases       288 non-null    int64
#  7   avg_filecourt_per1lakhcases     288 non-null    int64
#  8   pendingcases_count              256 non-null    float64
#  9   pending_casesperlakh            256 non-null    float64
#  10  criminal_count                  288 non-null    int64
#  11  criminal_perlakh                288 non-null    float64
# ...

# %%
x=df_line['year'].to_numpy()
y=df_line['dismissed_count'].to_numpy()

# %%
plt.plot(x, y,
    linewidth=0.5,
    linestyle='--',
    color='r',
    marker='o',
    markersize=10,
    markerfacecolor=(1, 0, 0, 0.1))


# 4. Add plot details
plt.title('Plot of sin(x) vs x from 0 to 4 pi')
plt.xlabel('x (0 to 4 pi)')
plt.ylabel('sin(x)')
plt.legend(['sin(x)']) # list containing one string
plt.xticks(
    np.arange(0, 4*np.pi + np.pi/2, np.pi/2),
    ['0','pi/2','pi','3pi/2','2pi','5pi/2','3pi','7pi/2','4pi'])
plt.grid(True)


# 5. Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
data = {'year': [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010],
        'unemployment_rate': [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3]
       }
  
df = pd.DataFrame(data)
  
plt.plot(df['year'], df['unemployment_rate'], color='red', marker='o')
plt.title('unemployment rate vs year', fontsize=14)
plt.xlabel('year', fontsize=14)
plt.ylabel('unemployment rate', fontsize=14)
plt.grid(True)
plt.show()
