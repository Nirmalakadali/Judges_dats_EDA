# %%
import pandas as pd

# %%
df0=pd.read_csv('/home/nirmala/Videos/2010_filtered.csv')

# %%
df1=pd.read_csv('/home/nirmala/Videos/2011_filtered.csv')

# %%
df2=pd.read_csv('/home/nirmala/Videos/2012_filtered.csv')

# %%
df3=pd.read_csv('/home/nirmala/Videos/2013_filtered.csv')

# %%
df4=pd.read_csv('/home/nirmala/Videos/2014_filtered.csv')

# %%
df5=pd.read_csv('/home/nirmala/Videos/2015_filtered.csv')

# %%
df6=pd.read_csv('/home/nirmala/Videos/2016_filtered.csv')

# %%
df7=pd.read_csv('/home/nirmala/Videos/2017_filtered.csv')

# %%
df8=pd.read_csv('/home/nirmala/Videos/2018_filtered.csv')

# %%
df=pd.concat([df0,df1])
df=pd.concat([df,df2])
df=pd.concat([df,df3])
df=pd.concat([df,df4])
df=pd.concat([df,df5])
df=pd.concat([df,df6])
df=pd.concat([df,df7])
df=pd.concat([df,df8])

# %%
df
# Out:
#     year           state  dismissed_count  prison_count  withdrawal_count  \
# 0   2010  Andhra Pradesh            27690             0              1332
# 1   2010           Assam                0             0                 0
# 2   2010           Bihar                0             0                 0
# 3   2010      Chandigarh                0             0                 0
# 4   2010     Chattisgarh                0             0                 0
# ..   ...             ...              ...           ...               ...
# 27  2018       Telangana                0             0                 0
# 28  2018         Tripura                1            23                 0
# 29  2018   Uttar pradesh               75             9               535
# 30  2018     Uttarakhand                1           249                 0
# 31  2018     West Bengal                0          6281                 0
#
#     avg_decision_end_per1lakhcases  avg_fileend_per1lakhcases  \
# ...

# %%
df.to_csv('merged_final.csv', index=False)
df.to_csv('merged_final_copy_after_filter.csv', index=False)
